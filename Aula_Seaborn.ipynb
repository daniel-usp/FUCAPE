# %% [markdown]
# <a href="https://colab.research.google.com/github/daniel-usp/FUCAPE/blob/main/Aula_Seaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Gráficos Seaborn

# %%
import pandas as pd
import seaborn as sns
dados = pd.read_csv('https://s3.amazonaws.com/caelum-online-public/1039-seaborn/material/tips.csv')
dados.head()
